# %% [markdown]
# __Prajapati.Dhruvi__

# %% [markdown]
# __OCT-2__

# %% [markdown]
# Description : In this note book contains panadas , head ,body and tail of the cvs file and some changes in the columns and cleaning data.

# %% [markdown]
# __Importing pandas as pd__

# %%
import pandas as pd

# %% [markdown]
# __reading an csv file__

# %%
major = pd.read_csv('Survey-2024.csv')

# %% [markdown]
# __describing an file__

# %%
major.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?
# count                                          62.000000
# mean                                            3.580645
# std                                             1.079593
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000

# %% [markdown]
# __To see the columns in a Pandas DataFrame__

# %%
major.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
major.shape
# Out:
# (197, 90)

# %% [markdown]
# __Dimension of the table__

# %%
major.dtypes
# Out:
# Timestamp                                                                                                                                               object
# Which course are you enrolled in?                                                                                                                       object
# How did you hear about County College of Morris? [CCM Web site]                                                                                         object
# How did you hear about County College of Morris? [Social Media]                                                                                         object
# How did you hear about County College of Morris? [Community Event]                                                                                      object
#                                                                                                                                                         ...
# ...

# %% [markdown]
# __Head of the table (Data Set)__

# %%
major.head()
# Out:
#                     Timestamp Which course are you enrolled in?  \
# 0  2024/09/09 12:33:58 PM AST        CMP 128 Computer Science I
# 1   2024/09/09 6:00:11 PM AST                               NaN
# 2   2024/09/10 9:00:12 AM AST        CMP 128 Computer Science I
# 3  2024/09/10 12:34:53 PM AST        CMP 128 Computer Science I
# 4   2024/09/10 3:06:47 PM AST        CMP 128 Computer Science I
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# ...

# %% [markdown]
# __Tail of the data set (end)__

# %%
major.tail()
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 192                                       Don't recall
# 193                                                Yes
# 194                                                Yes
# 195                                                Yes
# 196                                                 No
#
#     How did you hear about County College of Morris? [Social Media]  \
# 192                                       Don't recall
# ...

# %% [markdown]
# __an rough sample of the table__

# %%
major.sample()
# Out:
#                       Timestamp            Which course are you enrolled in?  \
# 100  2024/09/12 12:35:40 PM AST  CMP 120 Foundations of Information Security
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 100                                                 No
#
#     How did you hear about County College of Morris? [Social Media]  \
# 100                                                 No
#
#     How did you hear about County College of Morris? [Community Event]  \
# 100                                                Yes
#
#     How did you hear about County College of Morris? [Family member or friend]  \
# 100                                                Yes
#
#     How did you hear about County College of Morris? [Current CCM student]  \
# 100                                                 No
#
#     How did you hear about County College of Morris? [CCM Alumni]  \
# 100                                                Yes
#
# ...

# %% [markdown]
# __an info of the table__

# %%
major.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 90 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                        197 non-null    object
# ...

# %% [markdown]
# ### __Changing the name of the columns__

# %%
major.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
rename_dict = {
    'How did you hear about County College of Morris? [CCM Web site]': 'CCM Web',
    'How did you hear about County College of Morris? [Social Media]': 'Social Media',
    'How did you hear about County College of Morris? [Community Event]': 'Community Event',
    'How did you hear about County College of Morris? [Family member or friend]': 'Family/Friend',
    'How did you hear about County College of Morris? [Current CCM student]': 'Current Student',
    'How did you hear about County College of Morris? [CCM Alumni]': 'CCM Alumni',
    'How did you hear about County College of Morris? [High School Teacher]': 'HS Teacher',
    'How did you hear about County College of Morris? [High School Counselor]': 'HS Counselor',
    'How did you hear about County College of Morris? [In-app advertisement]': 'In-app Ad',
    'How did you hear about County College of Morris? [Employer]': 'Employer',
    'How did you hear about County College of Morris? [Billboard]': 'Billboard',
    'How did you hear about County College of Morris? [Television]': 'Television',
    'How did you hear about County College of Morris? [Radio]': 'Radio',
    'How did you hear about County College of Morris? [Other]': 'Other',
}

 
major.rename(columns=rename_dict, inplace=True)
major
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 0    2024/09/09 12:33:58 PM AST                    CMP 128 Computer Science I
# 1     2024/09/09 6:00:11 PM AST                                           NaN
# 2     2024/09/10 9:00:12 AM AST                    CMP 128 Computer Science I
# 3    2024/09/10 12:34:53 PM AST                    CMP 128 Computer Science I
# 4     2024/09/10 3:06:47 PM AST                    CMP 128 Computer Science I
# ..                          ...                                           ...
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
# ...

# %%
major.rename(columns={
    'Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.': 'First Major Choice'
}, inplace=True)
major
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 0    2024/09/09 12:33:58 PM AST                    CMP 128 Computer Science I
# 1     2024/09/09 6:00:11 PM AST                                           NaN
# 2     2024/09/10 9:00:12 AM AST                    CMP 128 Computer Science I
# 3    2024/09/10 12:34:53 PM AST                    CMP 128 Computer Science I
# 4     2024/09/10 3:06:47 PM AST                    CMP 128 Computer Science I
# ..                          ...                                           ...
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
# ...

# %%
major.rename(columns={
    'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]': 'Affordable',
    'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'Location',
    'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]': 'Programs',
    'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]': 'Online',
    'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]': 'Referral',
    'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]': 'Faculty',
    'To what extent did the following impact your decision to attend County College of Morris? [College reputation]': 'Reputation',
    'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]': 'Financial_Aid',
    'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]': 'Scholarships',
    'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]': 'Small_Classes',
    'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]': 'Extracurriculars',
    'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]': 'Transfer_Credits',
    'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]': 'Negative_Experience',
    'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]': 'NJ_Stars',
    'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]': 'Transfer_to_4yr',
    'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]': 'College_Credit_HS',
}, inplace=True)
major
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 0    2024/09/09 12:33:58 PM AST                    CMP 128 Computer Science I
# 1     2024/09/09 6:00:11 PM AST                                           NaN
# 2     2024/09/10 9:00:12 AM AST                    CMP 128 Computer Science I
# 3    2024/09/10 12:34:53 PM AST                    CMP 128 Computer Science I
# 4     2024/09/10 3:06:47 PM AST                    CMP 128 Computer Science I
# ..                          ...                                           ...
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
# ...

# %%
major.rename(columns={
    'What motivated you to seek a computing degree/certificate at CCM? [To get a job in the computing field]': 'Get Job',
    'What motivated you to seek a computing degree/certificate at CCM? [Transfer to bachelor\'s level program]': 'Transfer to Bachelor\'s',
    'What motivated you to seek a computing degree/certificate at CCM? [Transfer credits back to HS degree (ShareTime, Challenger Program)]': 'Transfer HS Credits',
    'What motivated you to seek a computing degree/certificate at CCM? [Career Advancement]': 'Career Advancement',
    'What motivated you to seek a computing degree/certificate at CCM? [Career Change]': 'Career Change',
    'What motivated you to seek a computing degree/certificate at CCM? [Professional Development]': 'Professional Development',
    'What motivated you to seek a computing degree/certificate at CCM? [Job Displacement]': 'Job Displacement',
    'What motivated you to seek a computing degree/certificate at CCM? [Relocation]': 'Relocation',
    'What motivated you to seek a computing degree/certificate at CCM? [To keep current in tech industry]': 'Stay Current in Tech',
    'What motivated you to seek a computing degree/certificate at CCM? [IT Industry Certifications]': 'IT Certifications',
    'What motivated you to seek a computing degree/certificate at CCM? [Financial]': 'Financial',
    'What motivated you to seek a computing degree/certificate at CCM? [Personal Enrichment]': 'Personal Enrichment',
}, inplace=True)
major
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 0    2024/09/09 12:33:58 PM AST                    CMP 128 Computer Science I
# 1     2024/09/09 6:00:11 PM AST                                           NaN
# 2     2024/09/10 9:00:12 AM AST                    CMP 128 Computer Science I
# 3    2024/09/10 12:34:53 PM AST                    CMP 128 Computer Science I
# 4     2024/09/10 3:06:47 PM AST                    CMP 128 Computer Science I
# ..                          ...                                           ...
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
# ...

# %%
major.rename(
    columns=({'Age ':'AGE'}), 
   inplace=True,
)
major.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?', 'CCM Web',
#        'Social Media', 'Community Event', 'Family/Friend', 'Current Student',
#        'CCM Alumni', 'HS Teacher', 'HS Counselor', 'In-app Ad', 'Employer',
#        'Billboard', 'Television', 'Radio', 'Other', 'Affordable', 'Location',
#        'Programs', 'Online', 'Referral', 'Faculty', 'Reputation',
#        'Financial_Aid', 'Scholarships', 'Small_Classes', 'Extracurriculars',
#        'Transfer_Credits', 'Negative_Experience', 'NJ_Stars',
#        'Transfer_to_4yr', 'College_Credit_HS',
#        'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]',
# ...

# %%
major.rename(
    columns=({'What degree program are you currently enrolled in?':'MAJOR'}), 
   inplace=True,
)
major.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?', 'CCM Web',
#        'Social Media', 'Community Event', 'Family/Friend', 'Current Student',
#        'CCM Alumni', 'HS Teacher', 'HS Counselor', 'In-app Ad', 'Employer',
#        'Billboard', 'Television', 'Radio', 'Other', 'Affordable', 'Location',
#        'Programs', 'Online', 'Referral', 'Faculty', 'Reputation',
#        'Financial_Aid', 'Scholarships', 'Small_Classes', 'Extracurriculars',
#        'Transfer_Credits', 'Negative_Experience', 'NJ_Stars',
#        'Transfer_to_4yr', 'College_Credit_HS',
#        'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]',
# ...

# %%
major.rename(
    columns=({'Race/ethnicity':'Race'}), 
   inplace=True,
)
major.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?', 'CCM Web',
#        'Social Media', 'Community Event', 'Family/Friend', 'Current Student',
#        'CCM Alumni', 'HS Teacher', 'HS Counselor', 'In-app Ad', 'Employer',
#        'Billboard', 'Television', 'Radio', 'Other', 'Affordable', 'Location',
#        'Programs', 'Online', 'Referral', 'Faculty', 'Reputation',
#        'Financial_Aid', 'Scholarships', 'Small_Classes', 'Extracurriculars',
#        'Transfer_Credits', 'Negative_Experience', 'NJ_Stars',
#        'Transfer_to_4yr', 'College_Credit_HS',
#        'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]',
# ...

# %%
replace_map = {
    "I have a bachelors in Criminal Justice and came back to add an IT AS and cybersecurity certificate": "cybersecurity",
}
major['MAJOR'].replace(replace_map)
major
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 0    2024/09/09 12:33:58 PM AST                    CMP 128 Computer Science I
# 1     2024/09/09 6:00:11 PM AST                                           NaN
# 2     2024/09/10 9:00:12 AM AST                    CMP 128 Computer Science I
# 3    2024/09/10 12:34:53 PM AST                    CMP 128 Computer Science I
# 4     2024/09/10 3:06:47 PM AST                    CMP 128 Computer Science I
# ..                          ...                                           ...
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
# ...

# %% [markdown]
# __Value Count__

# %%
count_data = major.groupby(['First Major Choice','Race']).size().unstack(fill_value=0)
count_data
# Out:
# Race                                                Black/African American  \
# First Major Choice
# Art                                                                      1
# Biology                                                                  0
# Business                                                                 1
# Computer science                                                         0
# Cybersecurity                                                            1
# Data Analytics and Statistics                                            0
# Engineering                                                              0
# Exercise Science                                                         0
# First Choice                                                             9
# I did not change to any other major.                                     0
# I have a bachelors in Criminal Justice and came...                       0
# ...

# %%
count_data = major.groupby(['Financial_Aid','Gender']).size().unstack(fill_value=0)
count_data
# Out:
# Gender         Man  Prefer not to say  Woman
# Financial_Aid
# High Impact     46                  0     14
# No Impact       55                  0     10
# Some Impact     47                  2      6

# %%
value_counts = major['Financial_Aid'].value_counts()
value_counts
# Out:
# Financial_Aid
# No Impact      65
# High Impact    60
# Some Impact    55
# Name: count, dtype: int64

# %%
value_counts = major['First Major Choice'].value_counts()
value_counts
# Out:
# First Major Choice
# First Choice                                                                                          90
# Engineering                                                                                           10
# Business                                                                                               7
# Science                                                                                                7
# Nursing/Radiology                                                                                      3
# LIberal Arts                                                                                           2
# Computer science                                                                                       1
# Nursing                                                                                                1
# Data Analytics and Statistics                                                                          1
# ...

# %%
value_counts = major['MAJOR'].value_counts()
value_counts
# Out:
# MAJOR
# Computer Science                                           61
# Information Technology                                     36
# Information Security Certificate of Achievement            10
# ShareTime CSIP Program                                      8
# Undecided                                                   7
# CIS Game Development Option                                 7
# Non Degree seeking                                          6
# Mechanical Engineering                                      5
# Data Analytics Certificate of Achievement                   4
# Challenger Program                                          3
# Technical Studies, Applied Associate of Science             3
# Data science                                                3
# cybersecurity                                               2
# Digital Media Technology                                    2
# Mechanical Engineering Technology                           2
# ...

# %%
print(major['MAJOR'])
# Out:
# 0           Mechanical Engineering Technologies
# 1                    CIS Game Development Option
# 2                               Computer Science
# 3                         Mechanical Engineering
# 4                               Computer Science
#                          ...
# 192                       Information Technology
# 193                       Information Technology
# 194                             Computer Science
# 195                             Computer Science
# 196    Data Analytics Certificate of Achievement
# Name: MAJOR, Length: 197, dtype: object

# %%
print(major['Race'])
# Out:
# 0                                        White/Caucasian
# 1        Hispanic or Latino;White/Caucasian;Multi-Racial
# 2                               Hispanic or Latino;Asian
# 3                                     Hispanic or Latino
# 4                                                  Asian
#                              ...
# 192                               Black/African American
# 193            Hispanic or Latino;Black/African American
# 194                                   Hispanic or Latino
# 195    Hispanic or Latino;American Indian/Native Amer...
# 196                                      White/Caucasian
# Name: Race, Length: 197, dtype: object

# %%
value_counts = major['Race'].value_counts()
value_counts
# Out:
# Race
# White/Caucasian                                                                                                                                                                          70
# Hispanic or Latino                                                                                                                                                                       42
# Asian                                                                                                                                                                                    23
# Hispanic or Latino;White/Caucasian                                                                                                                                                       15
# Black/African American                                                                                                                                                                   15
# ...

# %% [markdown]
# ### __Droping/removing column__

# %%
major.drop('How did you hear about County College of Morris? [Radio]',
           axis=1,
          inplace=True,
          )
major.columns

# %%
major.drop('To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]',
           axis=1,
          inplace=True,
          )
major.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
major.plot()
# Out:
# <Axes: >

# %%
major.plot(kind = 'scatter', x = 'Gender', y = 'Race')
# Out:
# <Axes: xlabel='Gender', ylabel='Race'>

# %%
count_data.plot(kind='barh', stacked=True, figsize=(20,12))
plt.title('Distribution of Race/Ethnicity by First Major Choice')
plt.xlabel('First Major Choice')
plt.ylabel('Count of Students')
# Display the plot
plt.show()

# %%
count_data.plot(kind='barh', stacked=True, figsize=(10,6))
plt.title( 'Financial Aid as compare to Gender')
plt.xlabel('Financial Aid' )
plt.ylabel('Gender')
# Display the plot
plt.show()

# %% [markdown]
# __This graphs represent the Major changed or who had first major in It or Computer science feild__

# %%
value_counts = major['Financial_Aid'].value_counts()
value_counts.plot(kind='bar', color='skyblue')
plt.title('Financial Aid Distribution')
plt.xlabel('Financial Aid Status')
plt.ylabel('Count')  
plt.show()

# %%
value_counts = major['What motivated you to seek a computing degree/certificate at CCM?  [To get a job in the computing field]'].value_counts()
value_counts.plot(kind='bar', color='purple')
plt.title('Most Common Motivations to Seek Computing Degree')
plt.xlabel('Motivation Level')
plt.ylabel('Count')
plt.xticks(rotation=0)   
plt.show()

# %%
plt.figure(figsize=(10,9))
value_counts = major['MAJOR'].value_counts()
value_counts.plot(kind='barh')
plt.title('Frequency of Majors')
plt.xlabel('Count')
plt.ylabel('Major')
plt.show()
