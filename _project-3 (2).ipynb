# %% [markdown]
# ### Name : Prajapati.Dhruvi

# %% [markdown]
# ### Project-3

# %%
import requests
from yelpapi import YelpAPI
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from wordcloud import WordCloud
from collections import Counter

# %% [markdown]
# ### An api key from yelp

# %% [markdown]
# ### The 60 review of the resturant in San Franciso

# %%
# Define the headers
headers = {
    'Authorization': f'Bearer {api_key}',
}

# Yelp API endpoint for business search
url = 'https://api.yelp.com/v3/businesses/search'

# Search parameters (searching for businesses in a specific category, location, etc.)
# default putting them as san Francisco
params = {
    'term': 'restaurant',  # or any category of interest
    'location': 'San Francisco',  # or any city of choice
    'limit': 20  # Retrieve 20 businesses
}

# Make the API request
response = requests.get(url, headers=headers, params=params)
businesses = response.json()['businesses']

# Extract reviews for each business (3 reviews per business)
reviews = []
for business in businesses:
    business_id = business['id']
    reviews_url = f'https://api.yelp.com/v3/businesses/{business_id}/reviews'
    reviews_response = requests.get(reviews_url, headers=headers)
    reviews_data = reviews_response.json().get('reviews', [])
    for review in reviews_data:
        reviews.append(review['text'])

# Let's inspect the first few reviews
reviews[:60]
# Out:
# ["I don't generally post reviews that often, but honestly after visiting this place I had to say something ! What can I say about this place, actually what...",
#  "I don't usually write reviews, but this place blew me away! From the warm welcome to the lively dining room, everything was perfect. Fresh focaccia and...",
#  'Lauren was our server on a busy Saturday night. She made our dinner enjoyable, and checked in with us often. Quick refills on water and bread by all the...',
#  'Been here a few times & this restaurant has not failed me. The food AMAZING & the cocktails OMG Soo good . My server name was David, gave me immediate...',
#  'Food very good. Service was good in the beginning but kinda fell off in the end :/ Vibes of the restaurant are nice tho!',
#  'Great food.  The clam chowder is the best.  Good atmosphere with a beautiful view.  Superb service.  We had a great waiter for the evening.  Jorge is awesome.',
#  "Second time at Marufuku Ramen, and it won't be my last! The wait was 1.5 hours on a busy Saturday night (rookie mistake--make a reservation!), but trust me,...",
#  "Marufuku is nestled in Japantown mall - you can't miss it because there is always a long line. I recommend joining the Yelp waitlist ahead of time so that...",
#  "I've been to this location twice this past year. My boyfriend and I decided to eat here after watching Wicked (during its opening weekend). It was around...",
#  'Life-changing cioppino, loaded to the brim with sea creatures. No other SF cioppino even comes close. We make sure to hit Sotto Mare any and every time we...',
#  'Soto Mare. The iconic Italian-American seafood spot in North Beach. I finally had the chance to visit it last week. \n\nI arrived on a Sunday night shortly...',
#  'This week I am visiting family in Cupertino and attending a SF Symphony concert.  Decided to check Sotto Mare off my foodie bucket list.  Easy street...',
#  "The chicken kabob plate at Beit Rima is one of my all-time favorite meals I've had in SF. It is packed with flavor, and pairing it with rice + hummus is...",
#  'High quality authentic food here. We enjoyed everything we tried so far.\n\nMezze sampler: B+\nCreamy hummus and tasty baba ganoush.\nThere is also a yogurt...',
#  "The best middle eastern food I've eaten in SF! The location is super cute and sitting outside on a sunny day would be perfect for any lunch meeting. It's...",
#  'Found this place working nearby temporarily at SMMC. \nI LOVE it!!!\nKaterina is a hoot. She is passionate about her business, funny, not afraid to strike up...',
#  "This is a late night college spot that opened up a bit ago in nopa. I'm not sure about all the outstanding reviews - maybe a friends / family invite sort of...",
#  'Ambiance - casual\nService - very friendly, sweet staff here\n\nFood - i\'m a bit surprised at the raving reviews; I got a salad and "pizza" which was more like...',
#  'Great beat salad \nVery good looking server \nAnd a very nice setting \n\nWould suggest this to anyone in the neighborhood.',
#  'Great service even for my pretentious Friemd who feigned himself as sommelier credential buy just another arrogant tech bro with a startup that will make...',
#  "11:30am, Sunday \nHere to check out the Avocado Toast & linger over the New York Times. Since I was the first one here, didn't feel like I was taking up...",
#  'Services was okay. Ambiance was fine but food is very disappointing. We ordered burger with No melted cheese, meat with burn flavor, Super hard bread, it...',
#  "The service at Blind Butcher is top notch! The food served at this restaurant are carefully crafted to the taste of their customers. I can't recommend enough!",
#  'This is my first time coming to The Blind Butcher, Instagram reels send me here. Michael was my server and gave me great recommendations. I order the grill...',
#  "It's been decades since I dined at the original location on Larkin Street.  If you've tried them back then, you won't recognize the atmosphere, vibe, and...",
#  "The meal I had here at Bodega may have been one of the best in my life. This spot has great reviews online and was on Yelp's top restaurant list for San...",
#  "I'm so spoiled by SJ and OC Vietnamese food, and have not been impressed with any Viet spots in SF until I tried Bodega! This is more of an upscale spot, so...",
#  "Poached Hananese Chicken was so tender and delicious. Seafood noodle soup was also great. Everything we had were fantastic. I should've taken pictures...",
#  'Tried out Dabao Singapore in her new location inside Metreon where the Korean fast food was.\n\nI got seafood laksa $18.95 and it came out pretty fast.  About...',
#  'Been here twice now, once during their soft opening, and then a second time a week after. The place is conveniently inside the Metreon, and offers some of...',
#  'Had a wonderful family brunch at Horsefeather, the food was amazing and I would definitely come back. \n\nService was quick and friendly. We sat outside by...',
#  'I really wanted to like this place! I went on a date night here during SF Restaurant week for their fixed menu deal. Unfortunately, it seemed to be...',
#  'WF"Home" because why can\'t home be a bar with snacks?!\n\nPopped in the get a change of atmosphere and was greeted by a cool staff and even cooler bartender....',
#  'Ooooh! It was pure deliciousness \n\nWith my family being spread across the states, it was time to double as tourists in the City. No turkey. No dressing. No...',
#  'The best part of rainy days is being able to walk into a brunch spot like Bernal Heights Four Chairs that normally has over an hour wait and immediately get...',
#  'My friends and I made plans for Saturday brunch and decided to come early to avoid waiting in a long line - we arrived just before 10 and were seated...',
#  "Hands down, some of the best food I've had!\n\nWe came for my nieces birthday on a Sunday - it wasn't too busy. The space is a little tight, but it worked...",
#  "Visited Daeho with soem friends because we've heard so much about their famous galbijjim and beef soup. It's definitely not a spontaneous place to drop by...",
#  "Took my dad her since he said he haven't had good Korean food yet. I'm happy to report he was very happy with the meal. \n\nThe service was good. We sat down...",
#  "Our party of five was looking for a vegan-friendly restaurant and we were fortunate enough to discover Savor here on Yelp. \n\nBelieve the raves. It's a cozy,...",
#  'Chef Mo is amazing! Our dinner was perfectly paced and was basically a fine dining experience in a small cafe where the chef is also your server. We split 6...',
#  'No frills cafe with simple ambiance and fantastic food with a creative twist on Arabic/Mediterranean cuisine. The chef clearly is passionate about his...',
#  "This was a good spot coming back from north of San Francisco. It wasn't too crowded so we got seated immediately. They had very good hot tea which was great...",
#  'coming here 4 times in a row lately and every time still amazed me the spicy kimchi soup is definitely my favorite!! The taste is stable and as always the...',
#  "As an asian fusion spot, I'm never really expecting anything spectacular or anything authentic. I came with a friend and we just got a quick bite of food...",
#  'Arabic comfort food and it\'s divine.\n\nBeit Rima ("Rima\'s House") serves savory, delicious food and dishes I haven\'t experienced anywhere else. \n\nWhen a meal...',
#  'Came here on a Friday night with some coworkers. Since we were a bigger party we made a reservation but the restaurant is pretty small. Once we got in we...',
#  'This casual but robust place has quite a bit of charm. The food is very good. Its light, fresh and IMHO is good quality. Vegetarian/pescatarian so cannot...',
#  'Finally made a point to check this spot out after passing by numerous times and saying, "that place looks cute, we should check it out sometime!" I\'m...',
#  "Such a cute date spot for drinks and bites!\nSat inside by the window as we were only in for one drink- definitely encapsulated the 'snug' vibe with the...",
#  'The Snug is a yearly tradition for us, and it never disappoints! Their Brown Butter Coffee is nothing short of legendary. The smooth blend of coffee, the...',
#  'Authentic good Thai food with groovy decorations and friendly service in downtown San Francisco.',
#  'I wanted to transport myself to Thailand and this was the place to be!! The Chicken Khao Soi and Thai Iced Tea were a DREAM duo and it was one of the most...',
#  'The ambiance is nice and the service was good. The food was okay. I got the Gra Prao with tofu and found the rice too overcooked and sticky. I tried the pad...',
#  "Homey Italian restaurant in the Richmond! Feels like i'm eating at someone's nonna's house and I absolutely love the movies projected onto the walls in the...",
#  "I'm betting on a bright future for Bettola! Located in the heart of San Francisco's Richmond District along the busy Clement Street corridor, Bettola is...",
#  'I recently returned to Bettola.  It appears as though they changed their service model.  Now the restaurant offers a traditional process of sitting down,...',
#  'Good service, checked in multiple times with us. Great food, especially liked the squid. a good place to enjoy drinks and also enjoy some appetizers while...',
#  "amazing lunch. we had chicken and crab katsu \n\nhighly recommend it \n\nit's very beautiful decorated too. nice place to bring a date or a friend",
#  "Great food! I got the cheese katsu and it was phenomenal! The service was amazing, as well  if you're in the area, stop by here!! You won't regret it"]

# %%
# Download stopwords if needed
nltk.download('stopwords')

# Define stopwords
stop_words = set(stopwords.words('english'))

# Define the cleaning function
def clean_review(review_text):
    # Remove non-alphabetic characters
    review_text = re.sub(r'[^a-zA-Z\s]', '', review_text.lower())
    
    # Remove stopwords
    review_text = ' '.join([word for word in review_text.split() if word not in stop_words])
    
    return review_text

# Assuming 'reviews' is the list of reviews you want to clean
# Clean all reviews
cleaned_reviews = [clean_review(review) for review in reviews]

# Let's inspect the first 5 cleaned reviews
print(cleaned_reviews[:5])
# Out:
# ['dont generally post reviews often honestly visiting place say something say place actually', 'dont usually write reviews place blew away warm welcome lively dining room everything perfect fresh focaccia', 'lauren server busy saturday night made dinner enjoyable checked us often quick refills water bread', 'times restaurant failed food amazing cocktails omg soo good server name david gave immediate', 'food good service good beginning kinda fell end vibes restaurant nice tho']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dhruviprajapati/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #### Cleaned 5 review

# %% [markdown]
# #### Categorize reviews into positive, negative, and neutral

# %%
def get_textblob_sentiment(review_text):
    # Create a TextBlob object
    blob = TextBlob(review_text)
    
    # Get the sentiment polarity (ranges from -1 (negative) to 1 (positive))
    return blob.sentiment.polarity

# Get TextBlob sentiment scores for each review
textblob_sentiments = [get_textblob_sentiment(review) for review in cleaned_reviews]

# Classify as positive, neutral, or negative
def classify_sentiment(score):
    if score > 0:
        return 'positive'
    elif score < 0:
        return 'negative'
    else:
        return 'neutral'

textblob_sentiment_labels = [classify_sentiment(score) for score in textblob_sentiments]

# Check sentiment distribution
from collections import Counter
textblob_sentiment_distribution = Counter(textblob_sentiment_labels)
textblob_sentiment_distribution
# Out:
# Counter({'positive': 53, 'negative': 6, 'neutral': 1})

# %% [markdown]
# ### Sentiment Analysis with TextBlob and NaiveBayesAnalyzer

# %%
# Initialize NaiveBayesAnalyzer
analyzer = NaiveBayesAnalyzer()

# Function to get the sentiment label using NaiveBayesAnalyzer
def get_nb_sentiment(review_text):
    # Analyze sentiment using NaiveBayesAnalyzer
    analysis = analyzer.analyze(review_text)
    return analysis.classification  # Access the 'classification' attribute, not 'classify'

# Get NaiveBayesAnalyzer sentiment labels for each cleaned review
nb_sentiment_labels = [get_nb_sentiment(review) for review in cleaned_reviews]

# Check sentiment distribution
nb_sentiment_distribution = Counter(nb_sentiment_labels)
print(nb_sentiment_distribution)
# Out:
# Counter({'pos': 45, 'neg': 15})

# %% [markdown]
# ### Visualize Sentiment with a Donut Chart

# %%
# Calculate sentiment percentages for TextBlob
textblob_percentages = [textblob_sentiment_distribution['positive'] / len(cleaned_reviews) * 100,
                        textblob_sentiment_distribution['neutral'] / len(cleaned_reviews) * 100,
                        textblob_sentiment_distribution['negative'] / len(cleaned_reviews) * 100]

# Calculate sentiment percentages for NaiveBayesAnalyzer
nb_percentages = [nb_sentiment_distribution['pos'] / len(cleaned_reviews) * 100,
                  nb_sentiment_distribution['neu'] / len(cleaned_reviews) * 100,
                  nb_sentiment_distribution['neg'] / len(cleaned_reviews) * 100]

# Create a function for the donut chart
def plot_donut_chart(labels, sizes, title):
    fig, ax = plt.subplots(figsize=(7, 7))
    wedges, texts, autotexts = ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
    ax.set_title(title)
    plt.show()

# Plot donut chart for TextBlob
plot_donut_chart(['Positive', 'Neutral', 'Negative'], textblob_percentages, 'TextBlob Sentiment Analysis')

# Plot donut chart for NaiveBayesAnalyzer
plot_donut_chart(['Positive', 'Neutral', 'Negative'], nb_percentages, 'NaiveBayesAnalyzer Sentiment Analysis')

# %% [markdown]
# #### WordCloud Visualization

# %% [markdown]
# ##### This is coolest way to show review

# %%
# Join all the cleaned reviews into a single string
all_reviews = ' '.join(cleaned_reviews)

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, max_words=20, background_color='white').generate(all_reviews)

# Display the WordCloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
